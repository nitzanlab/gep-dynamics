# %% [markdown]
# # Running the comparator between developmental stages in Zepp et. al.

# %%
# %%time
# %load_ext autoreload
# %autoreload 2

import os
import warnings


import pandas as pd
import scanpy as sc

from sklearn.exceptions import ConvergenceWarning

from gepdynamics import _utils
from gepdynamics import comparator

# Move to the project's home directory, as defined in _constants
_utils.cd_proj_home()
print(os.getcwd())
# Out:
# /cs/labs/mornitzan/yotamcon/gep-dynamics
# CPU times: user 3.48 s, sys: 1.71 s, total: 5.2 s
# Wall time: 1min 45s

# %%
# %%time
results_dir = _utils.set_dir('results_zepp')

split_adatas_dir = results_dir.joinpath('split_adatas')

stages = ['E12', 'E15', 'E17', 'P3', 'P7', 'P15', 'P42']

split_adatas = {stage: sc.read_h5ad(split_adatas_dir.joinpath(f'{stage}_GEPs.h5ad')) for stage in stages}
# Out:
# CPU times: user 2.29 s, sys: 2.25 s, total: 4.54 s
# Wall time: 27.4 s

# %%
for stage in stages:
    tmp = split_adatas[stage]
    # pd.Categorical(adata.obs['timesimple'].map(
    #    dict(zip(pd.Categorical(adata.obs['timesimple']).categories, adata.uns['timesimple_colors']))))
    field_1 = 'compartment'
    field_2 = 'celltype'
    tmp.obsm['row_colors'] = pd.concat([
        tmp.obs[field_1].map(tmp.uns[f'{field_1}_colors_dict']),
        tmp.obs[field_2].map(tmp.uns[f'{field_2}_colors_dict'])], axis=1)

# %%
# %%time

pairs = [(stages[i], stages[i + 1]) for i in range(len(stages) -1)]

for stage_a, stage_b in pairs:
    comparison_dir = _utils.set_dir(results_dir.joinpath(f"{stage_a}_{stage_b}"))
    
    adata_a = split_adatas[stage_a]
    adata_b = split_adatas[stage_b]
    
    if os.path.exists(comparison_dir.joinpath('comparator.npz')):
        cmp = comparator.Comparator.load_from_file(comparison_dir.joinpath('comparator.npz'), adata_a, adata_b)
    else:
        cmp = comparator.Comparator(adata_a, adata_a.obsm['usages'], adata_b, comparison_dir, 'torchnmf', device='cuda', max_nmf_iter=1000, verbosity=1)
        
        print('decomposing')
        cmp.extract_geps_on_jointly_hvgs()
        cmp.decompose_b(repeats = 20)
    
    cmp.examine_adata_a_decomposition_on_jointly_hvgs()
    
    cmp.print_errors()
    cmp.examine_adata_b_decompositions()
    cmp.plot_decomposition_comparisons()
    
    cmp.calculate_fingerprints()
    
    print('running GSEA')
    cmp.run_gsea(gprofiler_kwargs=dict(organism='mmusculus', sources=['GO:BP', 'WP', 'REAC', 'KEGG', 'TF', 'HP']))

    cmp.save_to_file(comparison_dir.joinpath('comparator.npz'))
# Out:
# dn_16 error =  5114335.6
# dn_17 error =  5084008.0
# dn_18 error =  5057438.8
# dn_19 error =  5021209.0
# E12 error =  6034421.6
# E12e1 error =  5781610.4
# E12e2 error =  5660207.4
# E12e3 error =  5529197.7
# Number of edges=464
# Number of edges=1500
# running GSEA
# Directory "results_zepp/E15_E17" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E15_E17
# decomposing
# Extracting A GEPs on jointly highly variable genes
# Decomposing B using A GEPs and no additional GEPs
# beta 1 loss = 4673905.607779528, # iterations was 90
# Decomposing B de-novo
# beta 1 loss = 3985083.457523105, # iterations was 500
# beta 1 loss = 3938755.9288857915, # iterations was 350
# beta 1 loss = 3918052.0249028774, # iterations was 490
# beta 1 loss = 3897030.6062946157, # iterations was 370
# Decomposing B using A GEPs and up to 3 additional GEPs
# Working on added rank = 1
# repeat 0, after 66 iterations reached error =  4435692.4
# repeat 3, after 66 iterations reached error =  4435685.8
# repeat 4, after 64 iterations reached error =  4435666.7
# repeat 6, after 67 iterations reached error =  4435654.5
# repeat 8, after 67 iterations reached error =  4435652.0
# repeat 12, after 68 iterations reached error =  4435614.3
# Working on added rank = 2
# repeat 0, after 79 iterations reached error =  4340633.5
# repeat 1, after 74 iterations reached error =  4340623.9
# repeat 5, after 79 iterations reached error =  4340592.5
# repeat 7, after 130 iterations reached error =  4326299.6
# Working on added rank = 3
# repeat 0, after 122 iterations reached error =  4231137.9
# repeat 4, after 121 iterations reached error =  4230911.0
# repeat 14, after 124 iterations reached error =  4230872.0
# Directory "results_zepp/E15_E17/decompositions" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E15_E17/decompositions
# dn_18 error =  3985084.4
# dn_19 error =  3938757.3
# dn_20 error =  3918053.0
# dn_21 error =  3897031.5
# E15 error =  4673907.1
# E15e1 error =  4435614.3
# E15e2 error =  4326299.6
# E15e3 error =  4230872.0
# Directory "results_zepp/E15_E17/comparisons" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E15_E17/comparisons
# Number of edges=358
# Number of edges=1882
# running GSEA
# Directory "results_zepp/E15_E17/programs_top_genes" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E15_E17/programs_top_genes
# Directory "results_zepp/E15_E17/programs_gsea" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E15_E17/programs_gsea
# Directory "results_zepp/E17_P3" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E17_P3
# decomposing
# Extracting A GEPs on jointly highly variable genes
# Decomposing B using A GEPs and no additional GEPs
# beta 1 loss = 6693790.604601702, # iterations was 90
# Decomposing B de-novo
# beta 1 loss = 5614681.826982715, # iterations was 210
# beta 1 loss = 5569604.879499175, # iterations was 330
# beta 1 loss = 5504491.879589373, # iterations was 330
# beta 1 loss = 5460286.826245356, # iterations was 280
# Decomposing B using A GEPs and up to 3 additional GEPs
# Working on added rank = 1
# repeat 0, after 51 iterations reached error =  6528199.3
# repeat 3, after 54 iterations reached error =  6528175.6
# repeat 4, after 48 iterations reached error =  6528103.2
# repeat 10, after 55 iterations reached error =  6528036.7
# Working on added rank = 2
# repeat 0, after 195 iterations reached error =  6330872.5
# repeat 2, after 205 iterations reached error =  6330363.0
# repeat 3, after 165 iterations reached error =  6329635.7
# repeat 15, after 203 iterations reached error =  6328661.0
# Working on added rank = 3
# repeat 0, after 210 iterations reached error =  6216516.8
# repeat 1, after 328 iterations reached error =  6213212.8
# repeat 2, after 239 iterations reached error =  6211633.9
# repeat 7, after 289 iterations reached error =  6209062.6
# repeat 19, after 246 iterations reached error =  6208707.4
# Directory "results_zepp/E17_P3/decompositions" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E17_P3/decompositions
# dn_15 error =  5614683.6
# dn_16 error =  5569606.6
# dn_17 error =  5504493.4
# dn_18 error =  5460288.0
# E17 error =  6693792.1
# E17e1 error =  6528036.7
# E17e2 error =  6328661.0
# E17e3 error =  6208707.4
# Directory "results_zepp/E17_P3/comparisons" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E17_P3/comparisons
# Number of edges=306
# Number of edges=3104
# running GSEA
# Directory "results_zepp/E17_P3/programs_top_genes" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E17_P3/programs_top_genes
# Directory "results_zepp/E17_P3/programs_gsea" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/E17_P3/programs_gsea
# Directory "results_zepp/P3_P7" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P3_P7
# decomposing
# Extracting A GEPs on jointly highly variable genes
# Decomposing B using A GEPs and no additional GEPs
# beta 1 loss = 6472322.151839869, # iterations was 90
# Decomposing B de-novo
# beta 1 loss = 6145893.318835168, # iterations was 180
# beta 1 loss = 6068279.712947207, # iterations was 190
# beta 1 loss = 5998876.640734291, # iterations was 430
# beta 1 loss = 5953360.2589965835, # iterations was 260
# Decomposing B using A GEPs and up to 3 additional GEPs
# Working on added rank = 1
# repeat 0, after 143 iterations reached error =  6373296.4
# repeat 5, after 140 iterations reached error =  6373286.7
# repeat 9, after 123 iterations reached error =  6373221.3
# Working on added rank = 2
# repeat 0, after 101 iterations reached error =  6329737.5
# repeat 1, after 98 iterations reached error =  6328449.6
# repeat 10, after 281 iterations reached error =  6316056.9
# repeat 12, after 206 iterations reached error =  6314397.3
# Working on added rank = 3
# repeat 0, after 146 iterations reached error =  6296058.6
# repeat 1, after 121 iterations reached error =  6295991.9
# repeat 3, after 114 iterations reached error =  6295904.7
# repeat 5, after 251 iterations reached error =  6282688.2
# repeat 11, after 254 iterations reached error =  6276524.6
# repeat 13, after 200 iterations reached error =  6273101.3
# repeat 19, after 238 iterations reached error =  6272283.8
# Directory "results_zepp/P3_P7/decompositions" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P3_P7/decompositions
# dn_16 error =  6145895.1
# dn_17 error =  6068280.9
# dn_18 error =  5998878.2
# dn_19 error =  5953361.9
# P3 error =  6472323.8
# P3e1 error =  6373221.3
# P3e2 error =  6314397.3
# P3e3 error =  6272283.8
# Directory "results_zepp/P3_P7/comparisons" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P3_P7/comparisons
# Number of edges=288
# Number of edges=2800
# running GSEA
# Directory "results_zepp/P3_P7/programs_top_genes" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P3_P7/programs_top_genes
# Directory "results_zepp/P3_P7/programs_gsea" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P3_P7/programs_gsea
# Directory "results_zepp/P7_P15" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P7_P15
# decomposing
# Extracting A GEPs on jointly highly variable genes
# Decomposing B using A GEPs and no additional GEPs
# beta 1 loss = 7724977.937781469, # iterations was 100
# Decomposing B de-novo
# beta 1 loss = 6971170.880204152, # iterations was 200
# beta 1 loss = 6946984.800847985, # iterations was 250
# beta 1 loss = 6922690.728818209, # iterations was 230
# beta 1 loss = 6896294.470468235, # iterations was 370
# Decomposing B using A GEPs and up to 3 additional GEPs
# Working on added rank = 1
# repeat 0, after 69 iterations reached error =  7482227.3
# repeat 3, after 67 iterations reached error =  7482125.9
# repeat 14, after 66 iterations reached error =  7482083.5
# Working on added rank = 2
# repeat 0, after 114 iterations reached error =  7305067.9
# repeat 1, after 130 iterations reached error =  7304969.6
# repeat 8, after 126 iterations reached error =  7304962.6
# repeat 10, after 134 iterations reached error =  7304914.2
# Working on added rank = 3
# repeat 0, after 165 iterations reached error =  7252046.6
# repeat 16, after 187 iterations reached error =  7251763.8
# Directory "results_zepp/P7_P15/decompositions" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P7_P15/decompositions
# dn_18 error =  6971172.3
# dn_19 error =  6946986.5
# dn_20 error =  6922692.3
# dn_21 error =  6896296.1
# P7 error =  7724979.5
# P7e1 error =  7482083.5
# P7e2 error =  7304914.2
# P7e3 error =  7251763.8
# Directory "results_zepp/P7_P15/comparisons" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P7_P15/comparisons
# Number of edges=332
# Number of edges=2768
# running GSEA
# Directory "results_zepp/P7_P15/programs_top_genes" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P7_P15/programs_top_genes
# Directory "results_zepp/P7_P15/programs_gsea" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P7_P15/programs_gsea
# Directory "results_zepp/P15_P42" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P15_P42
# decomposing
# Extracting A GEPs on jointly highly variable genes
# Decomposing B using A GEPs and no additional GEPs
# beta 1 loss = 7927977.675121593, # iterations was 80
# Decomposing B de-novo
# beta 1 loss = 7441914.425036405, # iterations was 130
# beta 1 loss = 7349194.7461203905, # iterations was 130
# beta 1 loss = 7283731.259699357, # iterations was 170
# beta 1 loss = 7227842.820828747, # iterations was 180
# Decomposing B using A GEPs and up to 3 additional GEPs
# Working on added rank = 1
# repeat 0, after 60 iterations reached error =  7830364.4
# repeat 3, after 61 iterations reached error =  7830155.6
# repeat 4, after 60 iterations reached error =  7830072.0
# repeat 5, after 73 iterations reached error =  7828958.5
# repeat 15, after 92 iterations reached error =  7827762.1
# Working on added rank = 2
# repeat 0, after 111 iterations reached error =  7726443.1
# repeat 2, after 292 iterations reached error =  7721360.2
# repeat 3, after 301 iterations reached error =  7721233.3
# repeat 4, after 176 iterations reached error =  7714018.8
# Working on added rank = 3
# repeat 0, after 204 iterations reached error =  7616250.2
# Directory "results_zepp/P15_P42/decompositions" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P15_P42/decompositions
# dn_13 error =  7441916.5
# dn_14 error =  7349196.9
# dn_15 error =  7283733.2
# dn_16 error =  7227844.4
# P15 error =  7927979.7
# P15e1 error =  7827762.1
# P15e2 error =  7714018.8
# P15e3 error =  7616250.2
# Directory "results_zepp/P15_P42/comparisons" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P15_P42/comparisons
# Number of edges=230
# Number of edges=2724
# running GSEA
# Directory "results_zepp/P15_P42/programs_top_genes" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P15_P42/programs_top_genes
# Directory "results_zepp/P15_P42/programs_gsea" does not exist.
# trying to create it at /cs/labs/mornitzan/yotamcon/gep-dynamics/results_zepp/P15_P42/programs_gsea
# CPU times: user 1d 22min 33s, sys: 2d 7h 47min 29s, total: 3d 8h 10min 3s
# Wall time: 10h 39min 12s

# %%
for stage_a, stage_b in pairs:
    comparison_dir = results_dir.joinpath(f"{stage_a}_{stage_b}", 'comparator.npz')
    
    adata_a = split_adatas[stage_a]
    adata_b = split_adatas[stage_b]
    
    cmp = comparator.Comparator.load_from_file(comparison_dir, adata_a, adata_b)
    break

# %% [markdown]
# ### Epithelial only comparator objects

# %%
# %%time

epi_split_adatas_dir = results_dir.joinpath('epi_split_adatas')

stages = ['E12', 'E15', 'E17', 'P3', 'P7', 'P15', 'P42']

epi_split_adatas = {stage: sc.read_h5ad(epi_split_adatas_dir.joinpath(f'epi_{stage}_GEPs.h5ad')) for stage in stages}
# Out:
# CPU times: user 1.57 s, sys: 567 ms, total: 2.14 s
# Wall time: 17 s

# %%
for stage in stages:
    tmp = epi_split_adatas[stage]

    field_1 = 'compartment'
    field_2 = 'celltype'
    tmp.obsm['row_colors'] = pd.concat([
        tmp.obs[field_1].map(tmp.uns[f'{field_1}_colors_dict']),
        tmp.obs[field_2].map(tmp.uns[f'{field_2}_colors_dict'])], axis=1)

# %%
# %%time

pairs = [(stages[i], stages[i + 1]) for i in range(len(stages) -1)]
pairs = [('P7', 'P15', )]

for stage_a, stage_b in pairs:
    comparison_dir = _utils.set_dir(results_dir.joinpath(f"epi_{stage_a}_{stage_b}"))
    
    adata_a = epi_split_adatas[stage_a]
    adata_b = epi_split_adatas[stage_b]
    
    if os.path.exists(comparison_dir.joinpath('comparator.npz')):
        cmp = comparator.Comparator.load_from_file(comparison_dir.joinpath('comparator.npz'), adata_a, adata_b)
    else:
        cmp = comparator.Comparator(adata_a, adata_a.obsm['usages'], adata_b, comparison_dir, 'sklearn', max_nmf_iter=1000, verbosity=1)
        
        print('decomposing')
        cmp.extract_geps_on_jointly_hvgs()
        cmp.decompose_b(repeats = 20)
    
    cmp.examine_adata_a_decomposition_on_jointly_hvgs()
    
    cmp.print_errors()
    cmp.examine_adata_b_decompositions()
    cmp.plot_decomposition_comparisons()
    
    cmp.calculate_fingerprints()
    
    print('running GSEA')
    cmp.run_gsea(gprofiler_kwargs=dict(organism='mmusculus', sources=['GO:BP', 'WP', 'REAC', 'KEGG', 'TF', 'HP']))

    cmp.save_to_file(comparison_dir.joinpath('comparator.npz'))
# Out:
# decomposing
# Extracting A GEPs on jointly highly variable genes
# Decomposing B using A GEPs and no additional GEPs
# Epoch 10 reached after 0.082 seconds, error: 1256.033738
# Epoch 20 reached after 0.142 seconds, error: 1254.574878
# Epoch 30 reached after 0.203 seconds, error: 1254.342756
# Epoch 40 reached after 0.262 seconds, error: 1254.275787
# Epoch 50 reached after 0.322 seconds, error: 1254.250174
# Epoch 60 reached after 0.381 seconds, error: 1254.238414
# Epoch 70 reached after 0.443 seconds, error: 1254.232136
# Epoch 80 reached after 0.502 seconds, error: 1254.228946
# Epoch 90 reached after 0.562 seconds, error: 1254.226704
# Epoch 100 reached after 0.624 seconds, error: 1254.225558
# Decomposing B de-novo
# Epoch 10 reached after 0.109 seconds, error: 1218.704845
# Epoch 20 reached after 0.202 seconds, error: 1211.940902
# Epoch 30 reached after 0.291 seconds, error: 1209.424760
# Epoch 40 reached after 0.379 seconds, error: 1208.058256
# Epoch 50 reached after 0.470 seconds, error: 1207.171280
# Epoch 60 reached after 0.559 seconds, error: 1206.530615
# Epoch 70 reached after 0.650 seconds, error: 1206.031820
# Epoch 80 reached after 0.742 seconds, error: 1205.649669
# Epoch 90 reached after 0.835 seconds, error: 1205.364468
# Epoch 100 reached after 0.931 seconds, error: 1205.133603
# Epoch 110 reached after 1.031 seconds, error: 1204.935527
# Epoch 120 reached after 1.129 seconds, error: 1204.766679
# Epoch 130 reached after 1.229 seconds, error: 1204.624423
# Epoch 140 reached after 1.331 seconds, error: 1204.475301
# Epoch 150 reached after 1.434 seconds, error: 1204.357194
# Epoch 160 reached after 1.540 seconds, error: 1204.237207
# Epoch 170 reached after 1.648 seconds, error: 1204.135219
# Epoch 180 reached after 1.758 seconds, error: 1204.028239
# Epoch 190 reached after 1.870 seconds, error: 1203.933086
# Epoch 200 reached after 1.987 seconds, error: 1203.853241
# Epoch 210 reached after 2.105 seconds, error: 1203.777284
# Epoch 220 reached after 2.228 seconds, error: 1203.710825
# Epoch 230 reached after 2.349 seconds, error: 1203.658901
# Epoch 240 reached after 2.475 seconds, error: 1203.610973
# Epoch 250 reached after 2.600 seconds, error: 1203.560966
# Epoch 260 reached after 2.731 seconds, error: 1203.510802
# Epoch 270 reached after 2.860 seconds, error: 1203.462401
# Epoch 280 reached after 2.996 seconds, error: 1203.418464
# Epoch 290 reached after 3.132 seconds, error: 1203.384965
# Epoch 300 reached after 3.271 seconds, error: 1203.357594
# Epoch 310 reached after 3.411 seconds, error: 1203.330482
# Epoch 320 reached after 3.557 seconds, error: 1203.303785
# Epoch 330 reached after 3.700 seconds, error: 1203.283113
# Epoch 340 reached after 3.846 seconds, error: 1203.263427
# Epoch 350 reached after 3.994 seconds, error: 1203.240728
# Epoch 360 reached after 4.147 seconds, error: 1203.219016
# Epoch 370 reached after 4.300 seconds, error: 1203.203640
# Epoch 380 reached after 4.457 seconds, error: 1203.191901
# Epoch 390 reached after 4.613 seconds, error: 1203.180265
# Epoch 400 reached after 4.772 seconds, error: 1203.168317
# Epoch 410 reached after 4.929 seconds, error: 1203.155642
# Epoch 420 reached after 5.091 seconds, error: 1203.142552
# Epoch 430 reached after 5.251 seconds, error: 1203.130188
# Epoch 440 reached after 5.416 seconds, error: 1203.118240
# Epoch 450 reached after 5.579 seconds, error: 1203.106292
# Epoch 460 reached after 5.766 seconds, error: 1203.089980
# Epoch 470 reached after 5.933 seconds, error: 1203.076577
# Epoch 480 reached after 6.103 seconds, error: 1203.066083
# Epoch 490 reached after 6.273 seconds, error: 1203.056524
# Epoch 500 reached after 6.447 seconds, error: 1203.048731
# Epoch 510 reached after 6.619 seconds, error: 1203.040939
# Epoch 520 reached after 6.797 seconds, error: 1203.034549
# Epoch 530 reached after 6.975 seconds, error: 1203.027327
# Epoch 540 reached after 7.155 seconds, error: 1203.014443
# Epoch 550 reached after 7.335 seconds, error: 1203.000104
# Epoch 560 reached after 7.517 seconds, error: 1202.990544
# Epoch 570 reached after 7.698 seconds, error: 1202.980569
# Epoch 580 reached after 7.882 seconds, error: 1202.973711
# Epoch 590 reached after 8.066 seconds, error: 1202.967736
# Epoch 600 reached after 8.256 seconds, error: 1202.962073
# Epoch 610 reached after 8.445 seconds, error: 1202.957086
# Epoch 620 reached after 8.636 seconds, error: 1202.952721
# Epoch 630 reached after 8.827 seconds, error: 1202.949344
# Epoch 640 reached after 9.020 seconds, error: 1202.945863
# Epoch 650 reached after 9.211 seconds, error: 1202.942434
# Epoch 660 reached after 9.407 seconds, error: 1202.939940
# Epoch 670 reached after 9.600 seconds, error: 1202.937239
# Epoch 680 reached after 9.799 seconds, error: 1202.935056
# Epoch 690 reached after 9.995 seconds, error: 1202.933082
# Epoch 700 reached after 10.193 seconds, error: 1202.930484
# Epoch 710 reached after 10.395 seconds, error: 1202.927886
# Epoch 720 reached after 10.600 seconds, error: 1202.924925
# Epoch 730 reached after 10.811 seconds, error: 1202.921236
# Epoch 740 reached after 11.013 seconds, error: 1202.917703
# Epoch 750 reached after 11.216 seconds, error: 1202.914793
# Epoch 760 reached after 11.420 seconds, error: 1202.912715
# Epoch 770 reached after 11.624 seconds, error: 1202.910533
# Epoch 780 reached after 11.830 seconds, error: 1202.908506
# Epoch 790 reached after 12.037 seconds, error: 1202.906792
# Epoch 800 reached after 12.244 seconds, error: 1202.905129
# Epoch 810 reached after 12.452 seconds, error: 1202.902895
# Epoch 820 reached after 12.663 seconds, error: 1202.900869
# Epoch 830 reached after 12.875 seconds, error: 1202.897647
# Epoch 840 reached after 13.087 seconds, error: 1202.894322
# Epoch 850 reached after 13.298 seconds, error: 1202.891932
# Epoch 860 reached after 13.510 seconds, error: 1202.890269
# Epoch 870 reached after 13.723 seconds, error: 1202.888659
# Epoch 10 reached after 0.111 seconds, error: 1216.746790
# Epoch 20 reached after 0.201 seconds, error: 1209.243979
# Epoch 30 reached after 0.290 seconds, error: 1206.417838
# Epoch 40 reached after 0.384 seconds, error: 1204.813367
# Epoch 50 reached after 0.474 seconds, error: 1203.754335
# Epoch 60 reached after 0.564 seconds, error: 1202.982128
# Epoch 70 reached after 0.658 seconds, error: 1202.420683
# Epoch 80 reached after 0.749 seconds, error: 1201.976497
# Epoch 90 reached after 0.841 seconds, error: 1201.596230
# Epoch 100 reached after 0.941 seconds, error: 1201.282648
# Epoch 110 reached after 1.041 seconds, error: 1201.008743
# Epoch 120 reached after 1.141 seconds, error: 1200.772980
# Epoch 130 reached after 1.246 seconds, error: 1200.562993
# Epoch 140 reached after 1.351 seconds, error: 1200.385459
# Epoch 150 reached after 1.458 seconds, error: 1200.231280
# Epoch 160 reached after 1.566 seconds, error: 1200.101142
# Epoch 170 reached after 1.676 seconds, error: 1199.975416
# Epoch 180 reached after 1.790 seconds, error: 1199.828269
# Epoch 190 reached after 1.909 seconds, error: 1199.732262
# Epoch 200 reached after 2.028 seconds, error: 1199.655002
# Epoch 210 reached after 2.150 seconds, error: 1199.583053
# Epoch 220 reached after 2.274 seconds, error: 1199.523708
# Epoch 230 reached after 2.403 seconds, error: 1199.472540
# Epoch 240 reached after 2.533 seconds, error: 1199.426842
# Epoch 250 reached after 2.669 seconds, error: 1199.380465
# Epoch 260 reached after 2.807 seconds, error: 1199.334920
# Epoch 270 reached after 2.949 seconds, error: 1199.298753
# Epoch 280 reached after 3.093 seconds, error: 1199.262690
# Epoch 290 reached after 3.238 seconds, error: 1199.226834
# Epoch 300 reached after 3.386 seconds, error: 1199.191551
# Epoch 310 reached after 3.540 seconds, error: 1199.161009
# Epoch 320 reached after 3.694 seconds, error: 1199.133854
# Epoch 330 reached after 3.854 seconds, error: 1199.108419
# Epoch 340 reached after 4.014 seconds, error: 1199.082931
# Epoch 350 reached after 4.179 seconds, error: 1199.062029
# Epoch 360 reached after 4.344 seconds, error: 1199.044932
# Epoch 370 reached after 4.514 seconds, error: 1199.029451
# Epoch 380 reached after 4.683 seconds, error: 1199.015221
# Epoch 390 reached after 4.858 seconds, error: 1199.002606
# Epoch 400 reached after 5.034 seconds, error: 1198.989470
# Epoch 410 reached after 5.214 seconds, error: 1198.976908
# Epoch 420 reached after 5.395 seconds, error: 1198.963928
# Epoch 430 reached after 5.582 seconds, error: 1198.952459
# Epoch 440 reached after 5.766 seconds, error: 1198.941617
# Epoch 450 reached after 5.955 seconds, error: 1198.931191
# Epoch 460 reached after 6.143 seconds, error: 1198.921182
# Epoch 470 reached after 6.335 seconds, error: 1198.910808
# Epoch 480 reached after 6.527 seconds, error: 1198.902415
# Epoch 490 reached after 6.728 seconds, error: 1198.895325
# Epoch 500 reached after 6.930 seconds, error: 1198.886463
# Epoch 510 reached after 7.129 seconds, error: 1198.877913
# Epoch 520 reached after 7.333 seconds, error: 1198.871813
# Epoch 530 reached after 7.537 seconds, error: 1198.865922
# Epoch 540 reached after 7.741 seconds, error: 1198.859771
# Epoch 550 reached after 7.948 seconds, error: 1198.852576
# Epoch 560 reached after 8.156 seconds, error: 1198.844548
# Epoch 570 reached after 8.366 seconds, error: 1198.835998
# Epoch 580 reached after 8.578 seconds, error: 1198.829012
# Epoch 590 reached after 8.793 seconds, error: 1198.822495
# Epoch 600 reached after 9.007 seconds, error: 1198.816187
# Epoch 610 reached after 9.223 seconds, error: 1198.810921
# Epoch 620 reached after 9.440 seconds, error: 1198.807376
# Epoch 630 reached after 9.658 seconds, error: 1198.804300
# Epoch 640 reached after 9.878 seconds, error: 1198.801276
# Epoch 650 reached after 10.100 seconds, error: 1198.798044
# Epoch 660 reached after 10.323 seconds, error: 1198.794186
# Epoch 670 reached after 10.548 seconds, error: 1198.790380
# Epoch 680 reached after 10.775 seconds, error: 1198.786887
# Epoch 690 reached after 11.002 seconds, error: 1198.783342
# Epoch 700 reached after 11.231 seconds, error: 1198.779171
# Epoch 710 reached after 11.460 seconds, error: 1198.775156
# Epoch 720 reached after 11.691 seconds, error: 1198.770307
# Epoch 730 reached after 11.924 seconds, error: 1198.766658
# Epoch 740 reached after 12.156 seconds, error: 1198.763008
# Epoch 750 reached after 12.388 seconds, error: 1198.757273
# Epoch 760 reached after 12.622 seconds, error: 1198.751017
# Epoch 770 reached after 12.858 seconds, error: 1198.747680
# Epoch 780 reached after 13.095 seconds, error: 1198.744656
# Epoch 790 reached after 13.333 seconds, error: 1198.742987
# Epoch 10 reached after 0.114 seconds, error: 1214.897527
# Epoch 20 reached after 0.206 seconds, error: 1206.158468
# Epoch 30 reached after 0.298 seconds, error: 1203.072629
# Epoch 40 reached after 0.393 seconds, error: 1201.379884
# Epoch 50 reached after 0.485 seconds, error: 1200.297047
# Epoch 60 reached after 0.577 seconds, error: 1199.553354
# Epoch 70 reached after 0.672 seconds, error: 1198.984414
# Epoch 80 reached after 0.764 seconds, error: 1198.509908
# Epoch 90 reached after 0.861 seconds, error: 1198.101623
# Epoch 100 reached after 0.964 seconds, error: 1197.758427
# Epoch 110 reached after 1.066 seconds, error: 1197.481002
# Epoch 120 reached after 1.169 seconds, error: 1197.231389
# Epoch 130 reached after 1.272 seconds, error: 1197.007414
# Epoch 140 reached after 1.378 seconds, error: 1196.808360
# Epoch 150 reached after 1.485 seconds, error: 1196.641133
# Epoch 160 reached after 1.595 seconds, error: 1196.501463
# Epoch 170 reached after 1.708 seconds, error: 1196.388001
# Epoch 180 reached after 1.825 seconds, error: 1196.295114
# Epoch 190 reached after 1.944 seconds, error: 1196.212460
# Epoch 200 reached after 2.070 seconds, error: 1196.130010
# Epoch 210 reached after 2.198 seconds, error: 1196.055444
# Epoch 220 reached after 2.329 seconds, error: 1195.989967
# Epoch 230 reached after 2.461 seconds, error: 1195.929346
# Epoch 240 reached after 2.602 seconds, error: 1195.878547
# Epoch 250 reached after 2.742 seconds, error: 1195.838357
# Epoch 260 reached after 2.889 seconds, error: 1195.802555
# Epoch 270 reached after 3.036 seconds, error: 1195.762100
# Epoch 280 reached after 3.192 seconds, error: 1195.727916
# Epoch 290 reached after 3.351 seconds, error: 1195.696816
# Epoch 300 reached after 3.510 seconds, error: 1195.661532
# Epoch 310 reached after 3.669 seconds, error: 1195.634664
# Epoch 320 reached after 3.835 seconds, error: 1195.612970
# Epoch 330 reached after 4.002 seconds, error: 1195.593681
# Epoch 340 reached after 4.173 seconds, error: 1195.573816
# Epoch 350 reached after 4.347 seconds, error: 1195.554160
# Epoch 360 reached after 4.524 seconds, error: 1195.535863
# Epoch 370 reached after 4.704 seconds, error: 1195.519971
# Epoch 380 reached after 4.888 seconds, error: 1195.505751
# Epoch 390 reached after 5.074 seconds, error: 1195.492472
# Epoch 400 reached after 5.265 seconds, error: 1195.480552
# Epoch 410 reached after 5.457 seconds, error: 1195.469782
# Epoch 420 reached after 5.653 seconds, error: 1195.457758
# Epoch 430 reached after 5.850 seconds, error: 1195.447092
# Epoch 440 reached after 6.051 seconds, error: 1195.434440
# Epoch 450 reached after 6.253 seconds, error: 1195.419278
# Epoch 460 reached after 6.460 seconds, error: 1195.404011
# Epoch 470 reached after 6.668 seconds, error: 1195.395907
# Epoch 480 reached after 6.879 seconds, error: 1195.389947
# Epoch 490 reached after 7.092 seconds, error: 1195.381738
# Epoch 500 reached after 7.308 seconds, error: 1195.375621
# Epoch 510 reached after 7.527 seconds, error: 1195.369817
# Epoch 520 reached after 7.746 seconds, error: 1195.361347
# Epoch 530 reached after 7.969 seconds, error: 1195.354236
# Epoch 540 reached after 8.194 seconds, error: 1195.347596
# Epoch 550 reached after 8.421 seconds, error: 1195.341531
# Epoch 560 reached after 8.650 seconds, error: 1195.335518
# Epoch 570 reached after 8.880 seconds, error: 1195.328930
# Epoch 580 reached after 9.112 seconds, error: 1195.321087
# Epoch 590 reached after 9.344 seconds, error: 1195.314289
# Epoch 600 reached after 9.577 seconds, error: 1195.308015
# Epoch 610 reached after 9.815 seconds, error: 1195.302577
# Epoch 620 reached after 10.057 seconds, error: 1195.296145
# Epoch 630 reached after 10.299 seconds, error: 1195.290080
# Epoch 640 reached after 10.544 seconds, error: 1195.283125
# Epoch 650 reached after 10.790 seconds, error: 1195.274132
# Epoch 660 reached after 11.036 seconds, error: 1195.266864
# Epoch 670 reached after 11.285 seconds, error: 1195.261478
# Epoch 680 reached after 11.535 seconds, error: 1195.257713
# Epoch 690 reached after 11.786 seconds, error: 1195.254052
# Epoch 700 reached after 12.039 seconds, error: 1195.250601
# Epoch 710 reached after 12.293 seconds, error: 1195.247673
# Epoch 720 reached after 12.547 seconds, error: 1195.243856
# Epoch 730 reached after 12.802 seconds, error: 1195.240666
# Epoch 740 reached after 13.058 seconds, error: 1195.237895
# Epoch 750 reached after 13.323 seconds, error: 1195.234496
# Epoch 760 reached after 13.580 seconds, error: 1195.230365
# Epoch 770 reached after 13.841 seconds, error: 1195.226234
# Epoch 780 reached after 14.104 seconds, error: 1195.222626
# Epoch 790 reached after 14.368 seconds, error: 1195.219959
# Epoch 800 reached after 14.632 seconds, error: 1195.217867
# Epoch 810 reached after 14.898 seconds, error: 1195.215514
# Epoch 820 reached after 15.164 seconds, error: 1195.212533
# Epoch 830 reached after 15.431 seconds, error: 1195.208350
# Epoch 840 reached after 15.699 seconds, error: 1195.206886
# Epoch 10 reached after 0.116 seconds, error: 1212.104472
# Epoch 20 reached after 0.209 seconds, error: 1202.534095
# Epoch 30 reached after 0.302 seconds, error: 1199.072975
# Epoch 40 reached after 0.398 seconds, error: 1197.085523
# Epoch 50 reached after 0.491 seconds, error: 1195.795185
# Epoch 60 reached after 0.584 seconds, error: 1194.907319
# Epoch 70 reached after 0.686 seconds, error: 1194.235006
# Epoch 80 reached after 0.786 seconds, error: 1193.717827
# Epoch 90 reached after 0.887 seconds, error: 1193.331000
# Epoch 100 reached after 0.992 seconds, error: 1193.038034
# Epoch 110 reached after 1.097 seconds, error: 1192.814267
# Epoch 120 reached after 1.203 seconds, error: 1192.637675
# Epoch 130 reached after 1.311 seconds, error: 1192.484434
# Epoch 140 reached after 1.419 seconds, error: 1192.329914
# Epoch 150 reached after 1.530 seconds, error: 1192.187957
# Epoch 160 reached after 1.649 seconds, error: 1192.064491
# Epoch 170 reached after 1.769 seconds, error: 1191.964030
# Epoch 180 reached after 1.895 seconds, error: 1191.878245
# Epoch 190 reached after 2.023 seconds, error: 1191.792453
# Epoch 200 reached after 2.155 seconds, error: 1191.712843
# Epoch 210 reached after 2.288 seconds, error: 1191.653158
# Epoch 220 reached after 2.429 seconds, error: 1191.605220
# Epoch 230 reached after 2.570 seconds, error: 1191.556230
# Epoch 240 reached after 2.719 seconds, error: 1191.509022
# Epoch 250 reached after 2.868 seconds, error: 1191.473667
# Epoch 260 reached after 3.025 seconds, error: 1191.441721
# Epoch 270 reached after 3.182 seconds, error: 1191.409984
# Epoch 280 reached after 3.342 seconds, error: 1191.379662
# Epoch 290 reached after 3.505 seconds, error: 1191.353432
# Epoch 300 reached after 3.677 seconds, error: 1191.329772
# Epoch 310 reached after 3.850 seconds, error: 1191.308839
# Epoch 320 reached after 4.030 seconds, error: 1191.290529
# Epoch 330 reached after 4.212 seconds, error: 1191.274108
# Epoch 340 reached after 4.400 seconds, error: 1191.256952
# Epoch 350 reached after 4.590 seconds, error: 1191.236542
# Epoch 360 reached after 4.784 seconds, error: 1191.214296
# Epoch 370 reached after 4.980 seconds, error: 1191.200183
# Epoch 380 reached after 5.179 seconds, error: 1191.186226
# Epoch 390 reached after 5.382 seconds, error: 1191.173476
# Epoch 400 reached after 5.587 seconds, error: 1191.161985
# Epoch 410 reached after 5.795 seconds, error: 1191.150494
# Epoch 420 reached after 6.007 seconds, error: 1191.138426
# Epoch 430 reached after 6.220 seconds, error: 1191.127512
# Epoch 440 reached after 6.434 seconds, error: 1191.117123
# Epoch 450 reached after 6.660 seconds, error: 1191.108360
# Epoch 460 reached after 6.902 seconds, error: 1191.101591
# Epoch 470 reached after 7.128 seconds, error: 1191.096029
# Epoch 480 reached after 7.361 seconds, error: 1191.090782
# Epoch 490 reached after 7.597 seconds, error: 1191.085219
# Epoch 500 reached after 7.830 seconds, error: 1191.075354
# Epoch 510 reached after 8.066 seconds, error: 1191.069058
# Epoch 520 reached after 8.304 seconds, error: 1191.062131
# Epoch 530 reached after 8.545 seconds, error: 1191.052213
# Epoch 540 reached after 8.787 seconds, error: 1191.046704
# Epoch 550 reached after 9.032 seconds, error: 1191.041981
# Epoch 560 reached after 9.278 seconds, error: 1191.038622
# Epoch 570 reached after 9.526 seconds, error: 1191.034949
# Epoch 580 reached after 9.776 seconds, error: 1191.029334
# Epoch 590 reached after 10.027 seconds, error: 1191.022040
# Epoch 600 reached after 10.282 seconds, error: 1191.016530
# Epoch 610 reached after 10.539 seconds, error: 1191.011650
# Epoch 620 reached after 10.796 seconds, error: 1191.007662
# Epoch 630 reached after 11.057 seconds, error: 1191.003883
# Epoch 640 reached after 11.318 seconds, error: 1191.000315
# Epoch 650 reached after 11.581 seconds, error: 1190.994752
# Epoch 660 reached after 11.845 seconds, error: 1190.989819
# Epoch 670 reached after 12.113 seconds, error: 1190.984677
# Epoch 680 reached after 12.381 seconds, error: 1190.979849
# Epoch 690 reached after 12.650 seconds, error: 1190.976962
# Epoch 700 reached after 12.920 seconds, error: 1190.973971
# Epoch 710 reached after 13.192 seconds, error: 1190.970980
# Epoch 720 reached after 13.468 seconds, error: 1190.968199
# Epoch 730 reached after 13.748 seconds, error: 1190.964630
# Epoch 740 reached after 14.027 seconds, error: 1190.961586
# Epoch 750 reached after 14.307 seconds, error: 1190.958018
# Epoch 760 reached after 14.588 seconds, error: 1190.952717
# Epoch 770 reached after 14.871 seconds, error: 1190.947627
# Epoch 780 reached after 15.157 seconds, error: 1190.942326
# Epoch 790 reached after 15.445 seconds, error: 1190.936816
# Epoch 800 reached after 15.732 seconds, error: 1190.933615
# Epoch 810 reached after 16.020 seconds, error: 1190.931306
# Epoch 820 reached after 16.307 seconds, error: 1190.929679
# Decomposing B using A GEPs and up to 3 additional GEPs
# Working on added rank = 1
# repeat 0, after 85 iterations reached error =  765225.1
# repeat 1, after 87 iterations reached error =  765219.2
# repeat 2, after 83 iterations reached error =  765214.8
# repeat 4, after 85 iterations reached error =  765213.8
# Working on added rank = 2
# repeat 0, after 277 iterations reached error =  747850.8
# repeat 2, after 254 iterations reached error =  747837.4
# repeat 8, after 232 iterations reached error =  747825.7
# Working on added rank = 3
# repeat 0, after 375 iterations reached error =  742620.9
# repeat 1, after 274 iterations reached error =  742433.5
# repeat 2, after 265 iterations reached error =  741789.0
# dn_8 error =  723470.5
# dn_9 error =  718492.5
# dn_10 error =  714259.4
# dn_11 error =  709156.6
# P7 error =  786540.5
# P7e1 error =  765213.8
# P7e2 error =  747825.7
# P7e3 error =  741789.0
# Number of edges=168
# Number of edges=228
# running GSEA
# CPU times: user 51min 10s, sys: 1h 18min 36s, total: 2h 9min 46s
# Wall time: 22min 8s

# %%
for stage_a, stage_b in pairs:
    comparison_dir = _utils.set_dir(results_dir.joinpath(f"epi_{stage_a}_{stage_b}"))
    
    adata_a = epi_split_adatas[stage_a]
    adata_b = epi_split_adatas[stage_b]
    
    cmp = comparator.Comparator.load_from_file(comparison_dir, adata_a, adata_b)
    break

# %%
var_names_gt_2 = sc.pp.filter_genes(epi_split_adatas['E15'].X, min_cells=2)[0]
np.sum(var_names_gt_2)
# Out:
# 15669

# %%
cmp
# Out:
# Comparator(adata_a=P15, adata_b=P42) at stage Decomposed. engine=sklearn.
